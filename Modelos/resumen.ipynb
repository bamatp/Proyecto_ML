# %% [markdown]
# # **Resumen**

# %% [markdown]
# #### **Escenario 1.1**: Mejor modelo Catboost con MinMax Scaler
#
# *Sin escalar los datos*
#
# - Mejor modelo: Catboost
#
#     - MAE: 36693.149460103275
#     - MSE: 2329186905.3668447
#     - RMSE: 48261.65046252402
#     - R2: 0.4100023044649125
#     - MAPE: 0.36838940906632817
#
# *Escalando los datos*
#
# **Standard Scaler**
#
# - Mejor modelo: Catboost
#     - MAE: 36693.02987915517
#     - MSE: 2329174316.910343
#     - RMSE: 48261.52004351234
#     - R2: 0.4100054932001356
#     - MAPE: 0.368390760777079
#
# **MinMax Scaler**
#
# - Mejor modelo: Catboost
#     - MAE: 36692.17078415343
#     - MSE: 2329132023.1720686
#     - RMSE: 48261.081869059555
#     - R2: 0.4100162064701012
#     - MAPE: 0.36836615312096077
#
# Los 10 salarios con menor predicción de error, se sitúan entre los $40.000 y los $160.000, alcanzado su mínimo en $16,6 de error.
#
# Los 10 salarios con mayor predicción de error, se sitúan entre los $255.000 y los $385.000, alcanzado su máximo en $256.000 de error.
#
# #### **Escenario 1.2**: Mejor modelo Catboost con MinMax Scaler
# - Se toman en cuenta únicamente trabajadores a tiempo completo
#
# *Sin escalar los datos*
#
# - Mejor modelo: Catboost
#     - MAE: 35609.91844539204
#     - MSE: 2151808347.502282
#     - RMSE: 46387.58829150619
#     - R2: 0.43414788583222075
#     - MAPE: 0.3320705738072271
#
# *Escalando los datos*
#
# **Standard Scaler**
#
# - Mejor modelo: Catboost
#     - MAE: 35618.409059632715
#     - MSE: 2151972271.247213
#     - RMSE: 46389.35515015501
#     - R2: 0.4341047794850691
#     - MAPE: 0.33212872869928656
#
# **MinMax Scaler**
#
# - Mejor modelo: Catboost
#     - MAE: 35596.83314365005
#     - MSE: 2151181851.9118342
#     - RMSE: 46380.83496350442
#     - R2: 0.43431263277856624
#     - MAPE: 0.3319783705807936
#
#
# Los 10 salarios con menor predicción de error, se sitúan entre los $12.171 y los $184.000, alcanzando su mínimo en $52,16 de error.
#
# Los 10 salarios con mayor error se sitúan entre $90.000 y $340.000, alcanzando su máximo en $189.442 de error.
#
#
# #### **Escenario 1.3**: Mejor modelo Catboost con MinMax Scaler
# - Se toman en cuenta únicamente trabajadores a tiempo completo y que teletrabajan el 100% de su jornada
#
# *Sin escalar los datos*
#
# - Mejor modelo: Catboost
#     - MAE: 34865.577310725705
#     - MSE:  2120085877.7855594
#     - RMSE: 46044.39029659921
#     - R2: 0.47120700696449425
#     - MAPE: 0.30757289025643963
#
# *Escalando los datos*
#
# **Standard Scaler**
#
# - Mejor modelo: Catboost
#     - MAE:  4876.774041292396
#     - MSE:  2121209404.9499156
#     - RMSE: 46056.589158880575
#     - R2: 0.4709267761973249
#     - MAPE: 0.3076275877002513
#
# **MinMax Scaler**
#
# - Mejor modelo: Catboost
#     - MAE: 34858.09826879538
#     - MSE: 2119235684.8594346
#     - RMSE: 46035.157052620496
#     - R2: 0.47141906255468224
#     - MAPE: 0.30753366630195667
#
# Los 10 salarios con menor predicción de error, se sitúan entre los $59.3030 y los $199.000, alcanzando su mínimo en $804,5.
#
# Los 10 salarios con mayor predicción de error se sitúan entre los $116.100 y los $318.300, alcanzando su máximo en $166.502.
#
# #### **Escenario 1.4**: Mejor modelo Catboost
# - Se toman en cuenta únicamente trabajadores de los puestos de trabajo más relevantes, a tiempo completo y que teletrabajan el 100% de su jornada
#
# *Sin escalar los datos*
#
# - Mejor modelo: Catboost
#     - MAE: 32730.79214977167
#     - MSE: 1762766259.1057818
#     - RMSE: 41985.31003941476
#     - R2: 0.5389777627833139
#     - MAPE: 0.42257207577692346
#
# *Escalando los datos*
#
# **Standard Scaler**
#
# - Mejor modelo: Catboost
#     - MAE: 32736.831499798438
#     - MSE: 1763139661.2463439
#     - RMSE: 41989.75662285201
#     - R2: 0.5388801056553005
#     - MAPE: 0.42262525838107506
#
# **MinMax Scaler**
#
# - Mejor modelo: Catboost
#     - MAE: 32755.134843219967
#     - MSE: 1766213204.1295798
#     - RMSE: 42026.33940910843
#     - R2: 0.5380762715627818
#     - MAPE: 0.42275926559852817
#
# Los 10 salarios con menor predicción de error, se sitúan entre los $78.000 y los $192.000, alcanzando su mínimo en $190.
#
# Los 10 salarios con mayor predicción de error se sitúan entre los $38.000 y los $315.300, alcanzando su máximo en $154.000.
#
# #### **Escenario 1.5**: Mejor modelo Castboost
# - Se toman en cuenta únicamente trabajadores de los puestos de trabajo más relevantes, a tiempo completo y que teletrabajan el 100% de su jornada
# - Ordinal encoder para los años de prestación de servicios
#
# *Sin escalar los datos*
#
# - Mejor modelo: Catboost
#     - MAE: 32662.730400706892
#     - MSE: 1762055606.635918
#     - RMSE: 41976.846077759554
#     - R2: 0.5391636221335527
#     - MAPE: 0.4225823910330713
#
# *Escalando los datos*
#
# **Standard Scaler**
#
# - Mejor modelo: Catboost
#     - MAE: 32667.583786251467
#     - MSE: 1762409762.592649
#     - RMSE: 41981.06433372847
#     - R2: 0.5390709985252595
#     - MAPE: 0.42261770057777603
#
# **MinMax Scaler**
#
# - Mejor modelo: Catboost
#     - MAE: 32686.340705702045
#     - MSE: 1765501956.526624
#     - RMSE: 42017.8766303894
#     - R2: 0.5382622865601961
#     - MAPE: 0.42276396331533744
#
# Los 10 salarios con menor predicción de error, se sitúan entre los $54.094 y los $239.000, alcanzando su mínimo en $297,8.
#
# Los 10 salarios con mayor predicción de error se sitúan entre los $38.000 y los $315.300, alcanzando su máximo en $151.383.
#
# #### **Escenario 1.6**: Mejor modelo Castboost
# - Se toman en cuenta únicamente trabajadores de los puestos de trabajo más relevantes, a tiempo completo y que teletrabajan el 100% de su jornada
# - Ordinal encoder para los años de prestación de servicios
# - Ordinal encoder para el nivel de experiencia
#
# *Sin escalar los datos*
#
# - Mejor modelo: Catboost
#     - MAE: 32766.27037427366
#     - MSE: 1758297634.6381316
#     - RMSE: 41932.05974714492
#     - R2: 0.5401464572932726
#     - MAPE: 0.4262213151970497
#
# *Escalando los datos*
#
# **Standard Scaler**
#
# - Mejor modelo: Catboost
#     - MAE: 32783.03927178129
#     - MSE: 1759321656.6778967
#     - RMSE: 41944.26846039751
#     - R2: 0.5398786413367934
#     - MAPE: 0.42637248896459456
#
# **MinMax Scaler**
#
# - Mejor modelo: Catboost
#     - MAE: 33761.40998529733
#     - MSE: 1843106759.2165124
#     - RMSE: 42931.41925462647
#     - R2: 0.5179660393578012
#     - MAPE: 0.45678686365730065
#
# Los 10 salarios con menor predicción de error, se sitúan entre los $54.094 y los $239.000, alcanzando su mínimo en $61.43.
#
# Los 10 salarios con mayor predicción de error se sitúan entre los $38.000 y los $315.300, alcanzando su máximo en $152.341.
