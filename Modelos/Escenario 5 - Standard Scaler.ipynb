# %% [markdown]
# # **ESCENARIO 5 - STANDARD SCALER**

# %% [markdown]
# - Importamos el dataset del escenario 5

# %%
import pandas as pd
Data_Science_Salaries = pd.read_csv("DS - Escenario 1.5.csv", sep = ",")

# %% [markdown]
# - Importamos las bibliotecas necesarias

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import Lasso
from sklearn.linear_model import Ridge
from sklearn.svm import SVR
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingRegressor
from lightgbm import LGBMRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.neural_network import MLPRegressor
from sklearn.neighbors import KNeighborsRegressor
from catboost import CatBoostRegressor
from sklearn.ensemble import AdaBoostRegressor
from sklearn.ensemble import BaggingRegressor
from sklearn import metrics

# %% [markdown]
# - Seleccionamos el target y las features del dataset

# %%
X = Data_Science_Salaries.drop('salary_in_usd', axis=1)
y = Data_Science_Salaries['salary_in_usd']

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1342 entries, 0 to 1341
# Columns: 130 entries, Unnamed: 0 to S
# dtypes: float64(1), int64(129)
# memory usage: 1.3 MB

# %%
X.columns = X.columns.astype(str)

# %% [markdown]
# - Hacemos el x e y split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20, random_state=42)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit(X_train)

X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

# %%
print("Total features shape:", X.shape)

print("Train features shape:", X_train.shape)
print("Train target shape:", y_train.shape)

print("Test features shape:", X_test.shape)
print("Test target shape:", y_test.shape)
# Out:
# Total features shape: (1342, 130)
# Train features shape: (1073, 130)
# Train target shape: (1073,)
# Test features shape: (269, 130)
# Test target shape: (269,)

# %% [markdown]
# - Linear Regression

# %%
lr = LinearRegression()
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
predictions_lr = lr.predict(X_test)

# %%
import numpy as np
mae_lr = metrics.mean_absolute_error(y_test,predictions_lr)
mse_lr = metrics.mean_squared_error(y_test,predictions_lr)
rmse_lr = np.sqrt(metrics.mean_squared_error(y_test,predictions_lr))
r2_lr = metrics.r2_score(y_test,predictions_lr)
mape_lr = metrics.mean_absolute_percentage_error(y_test,predictions_lr)

# %%
print('MAE :'," ", mae_lr)
print('MSE :'," ", mse_lr)
print('RMSE :'," ", rmse_lr) 
print('R2:'," ", r2_lr) 
print('MAPE:'," ", mape_lr)
# Out:
# MAE :   6.274624919316212e+16
# MSE :   2.097688090345428e+35
# RMSE :   4.580052500076203e+17
# R2:   -5.486154794478701e+25
# MAPE:   3317434097776.483

# %%
linear_regression = {
    'Metric': ['MAE', 'MSE', 'RMSE', 'R2', 'MAPE'],
    'Value': [mae_lr, mse_lr, rmse_lr, r2_lr, mape_lr]
}
linear_regression_results = pd.DataFrame(linear_regression)

# %%
linear_regression_results
# Out:
#   Metric         Value
# 0    MAE  6.274625e+16
# 1    MSE  2.097688e+35
# 2   RMSE  4.580053e+17
# 3     R2 -5.486155e+25
# 4   MAPE  3.317434e+12

# %% [markdown]
# - Logistic Regressor

# %%
lg = LogisticRegression()
lg.fit(X_train,y_train)
# Out:
# c:\Users\beama\anaconda3\envs\ramp_up\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
predictions_lg = lg.predict(X_test)

# %%
mae_lg = metrics.mean_absolute_error(y_test,predictions_lg)
mse_lg = metrics.mean_squared_error(y_test,predictions_lg)
rmse_lg = np.sqrt(metrics.mean_squared_error(y_test,predictions_lg))
r2_lg = metrics.r2_score(y_test,predictions_lg)
mape_lg = metrics.mean_absolute_percentage_error(y_test,predictions_lg)

# %%
print('MAE :'," ", mae_lg)
print('MSE :'," ", mse_lg)
print('RMSE :'," ", rmse_lg) 
print('R2:'," ", r2_lg) 
print('MAPE:'," ", mape_lg)
# Out:
# MAE :   44542.17843866171
# MSE :   3273297759.635688
# RMSE :   57212.741235110276
# R2:   0.14392333729536533
# MAPE:   0.5707760244590192

# %%
lg = {
    'Metric': ['MAE', 'MSE', 'RMSE', 'R2', 'MAPE'],
    'Value': [mae_lg, mse_lg, rmse_lg, r2_lg, mape_lg]
}
lg_results = pd.DataFrame(lg)

# %%
lg_results
# Out:
#   Metric         Value
# 0    MAE  4.454218e+04
# 1    MSE  3.273298e+09
# 2   RMSE  5.721274e+04
# 3     R2  1.439233e-01
# 4   MAPE  5.707760e-01

# %% [markdown]
# - Lasso

# %%
lasso = Lasso()
lasso.fit(X_train,y_train)
# Out:
# c:\Users\beama\anaconda3\envs\ramp_up\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.311e+11, tolerance: 4.067e+08
#   model = cd_fast.enet_coordinate_descent(
# Lasso()

# %%
predictions_lasso = lasso.predict(X_test)

# %%
mae_lasso = metrics.mean_absolute_error(y_test,predictions_lasso)
mse_lasso = metrics.mean_squared_error(y_test,predictions_lasso)
rmse_lasso = np.sqrt(metrics.mean_squared_error(y_test,predictions_lasso))
r2_lasso = metrics.r2_score(y_test,predictions_lasso)
mape_lasso = metrics.mean_absolute_percentage_error(y_test,predictions_lasso)

# %%
print('MAE :'," ", mae_lasso)
print('MSE :'," ", mse_lasso)
print('RMSE :'," ", rmse_lasso) 
print('R2:'," ", r2_lasso) 
print('MAPE:'," ", mape_lasso)
# Out:
# MAE :   35513.98497196206
# MSE :   2125724029.3803685
# RMSE :   46105.57481889114
# R2:   0.4440521863475283
# MAPE:   0.5269197530315586

# %%
lasso = {
    'Metric': ['MAE', 'MSE', 'RMSE', 'R2', 'MAPE'],
    'Value': [mae_lasso, mse_lasso, rmse_lasso, r2_lasso, mape_lasso]
}
lasso_results = pd.DataFrame(lasso)

# %%
lasso_results
# Out:
#   Metric         Value
# 0    MAE  3.551398e+04
# 1    MSE  2.125724e+09
# 2   RMSE  4.610557e+04
# 3     R2  4.440522e-01
# 4   MAPE  5.269198e-01

# %% [markdown]
# - Ridge

# %%
ridge = Ridge()
ridge.fit(X_train,y_train)
# Out:
# Ridge()

# %%
predictions_ridge = ridge.predict(X_test)

# %%
mae_ridge = metrics.mean_absolute_error(y_test,predictions_ridge)
mse_ridge = metrics.mean_squared_error(y_test,predictions_ridge)
rmse_ridge = np.sqrt(metrics.mean_squared_error(y_test,predictions_ridge))
r2_ridge = metrics.r2_score(y_test,predictions_ridge)
mape_ridge = metrics.mean_absolute_percentage_error(y_test,predictions_ridge)

# %%
print('MAE :'," ", mae_ridge)
print('MSE :'," ", mse_ridge)
print('RMSE :'," ", rmse_ridge) 
print('R2:'," ", r2_ridge) 
print('MAPE:'," ", mape_ridge)
# Out:
# MAE :   35059.2453032107
# MSE :   2027546255.053293
# RMSE :   45028.2828348283
# R2:   0.4697289525843542
# MAPE:   0.4859185443969232

# %%
ridge = {
    'Metric': ['MAE', 'MSE', 'RMSE', 'R2', 'MAPE'],
    'Value': [mae_ridge, mse_ridge, rmse_ridge, r2_ridge, mape_ridge]
}
ridge_results = pd.DataFrame(ridge)

# %%
ridge_results
# Out:
#   Metric         Value
# 0    MAE  3.505925e+04
# 1    MSE  2.027546e+09
# 2   RMSE  4.502828e+04
# 3     R2  4.697290e-01
# 4   MAPE  4.859185e-01

# %% [markdown]
# - Support Vector Machine

# %%
svm = SVR()
svm.fit(X_train,y_train)
# Out:
# SVR()

# %%
predictions_svm = svm.predict(X_test)

# %%
mae_svm = metrics.mean_absolute_error(y_test,predictions_svm)
mse_svm = metrics.mean_squared_error(y_test,predictions_svm)
rmse_svm = np.sqrt(metrics.mean_squared_error(y_test,predictions_svm))
r2_svm = metrics.r2_score(y_test,predictions_svm)
mape_svm = metrics.mean_absolute_percentage_error(y_test,predictions_svm)

# %%
print('MAE :'," ", mae_svm)
print('MSE :'," ", mse_svm)
print('RMSE :'," ", rmse_svm) 
print('R2:'," ", r2_svm) 
print('MAPE:'," ", mape_svm)
# Out:
# MAE :   49777.758239161434
# MSE :   3852074980.4286103
# RMSE :   62065.08664642796
# R2:   -0.007446231869956854
# MAPE:   1.0029118693558023

# %%
svm = {
    'Metric': ['MAE', 'MSE', 'RMSE', 'R2', 'MAPE'],
    'Value': [mae_svm, mse_svm, rmse_svm, r2_svm, mape_svm]
}
svm_results = pd.DataFrame(svm)

# %%
svm_results
# Out:
#   Metric         Value
# 0    MAE  4.977776e+04
# 1    MSE  3.852075e+09
# 2   RMSE  6.206509e+04
# 3     R2 -7.446232e-03
# 4   MAPE  1.002912e+00

# %% [markdown]
# - Decision Tree Regressor

# %%
dt = DecisionTreeRegressor()
dt.fit(X_train,y_train)
# Out:
# DecisionTreeRegressor()

# %%
predictions_dt = dt.predict(X_test)

# %%
mae_dt = metrics.mean_absolute_error(y_test,predictions_dt)
mse_dt = metrics.mean_squared_error(y_test,predictions_dt)
rmse_dt = np.sqrt(metrics.mean_squared_error(y_test,predictions_dt))
r2_dt = metrics.r2_score(y_test,predictions_dt)
mape_dt = metrics.mean_absolute_percentage_error(y_test,predictions_dt)

# %%
print('MAE :'," ", mae_dt)
print('MSE :'," ", mse_dt)
print('RMSE :'," ", rmse_dt) 
print('R2:'," ", r2_dt) 
print('MAPE:'," ", mape_dt)
# Out:
# MAE :   48107.408921933085
# MSE :   3933033139.0594797
# RMSE :   62713.89908991052
# R2:   -0.028619493622697778
# MAPE:   0.44695861927371155

# %%
dt = {
    'Metric': ['MAE', 'MSE', 'RMSE', 'R2', 'MAPE'],
    'Value': [mae_dt, mse_dt, rmse_dt, r2_dt, mape_dt]
}
dt_results = pd.DataFrame(dt)

# %%
dt_results
# Out:
#   Metric         Value
# 0    MAE  4.810741e+04
# 1    MSE  3.933033e+09
# 2   RMSE  6.271390e+04
# 3     R2 -2.861949e-02
# 4   MAPE  4.469586e-01

# %% [markdown]
# - Random Forest Regressor

# %%
rf = RandomForestRegressor()
rf.fit(X_train,y_train)
# Out:
# RandomForestRegressor()

# %%
predictions_rf = rf.predict(X_test)

# %%
mae_rf = metrics.mean_absolute_error(y_test,predictions_rf)
mse_rf = metrics.mean_squared_error(y_test,predictions_rf)
rmse_rf = np.sqrt(metrics.mean_squared_error(y_test,predictions_rf))
r2_rf = metrics.r2_score(y_test,predictions_rf)
mape_rf = metrics.mean_absolute_percentage_error(y_test,predictions_rf)

# %%
print('MAE :'," ", mae_rf)
print('MSE :'," ", mse_rf)
print('RMSE :'," ", rmse_rf) 
print('R2:'," ", r2_rf) 
print('MAPE:'," ", mape_rf)
# Out:
# MAE :   38264.6331598513
# MSE :   2512230126.642955
# RMSE :   50122.152055183695
# R2:   0.3429679361030977
# MAPE:   0.4347033062279202

# %%
rf = {
    'Metric': ['MAE', 'MSE', 'RMSE', 'R2', 'MAPE'],
    'Value': [mae_rf, mse_rf, rmse_rf, r2_rf, mape_rf]
}
rf_results = pd.DataFrame(rf)

# %%
rf_results
# Out:
#   Metric         Value
# 0    MAE  3.826463e+04
# 1    MSE  2.512230e+09
# 2   RMSE  5.012215e+04
# 3     R2  3.429679e-01
# 4   MAPE  4.347033e-01

# %% [markdown]
# - Gradient Boosting Regressor

# %%
gbc = GradientBoostingRegressor()
gbc.fit(X_train,y_train)
# Out:
# GradientBoostingRegressor()

# %%
predictions_gbc = gbc.predict(X_test)

# %%
mae_gbc = metrics.mean_absolute_error(y_test,predictions_gbc)
mse_gbc = metrics.mean_squared_error(y_test,predictions_gbc)
rmse_gbc = np.sqrt(metrics.mean_squared_error(y_test,predictions_gbc))
r2_gbc = metrics.r2_score(y_test,predictions_gbc)
mape_gbc = metrics.mean_absolute_percentage_error(y_test,predictions_gbc)

# %%
print('MAE :'," ", mae_gbc)
print('MSE :'," ", mse_gbc)
print('RMSE :'," ", rmse_gbc) 
print('R2:'," ", r2_gbc) 
print('MAPE:'," ", mape_gbc)
# Out:
# MAE :   33309.96675234632
# MSE :   1815750164.501188
# RMSE :   42611.62006426402
# R2:   0.5251207023388631
# MAPE:   0.4158271521607702

# %%
gbc = {
    'Metric': ['MAE', 'MSE', 'RMSE', 'R2', 'MAPE'],
    'Value': [mae_gbc, mse_gbc, rmse_gbc, r2_gbc, mape_gbc]
}
gbc_results = pd.DataFrame(gbc)

# %%
gbc_results
# Out:
#   Metric         Value
# 0    MAE  3.330997e+04
# 1    MSE  1.815750e+09
# 2   RMSE  4.261162e+04
# 3     R2  5.251207e-01
# 4   MAPE  4.158272e-01

# %% [markdown]
# - KNN Regressor

# %%
knn = KNeighborsRegressor()
knn.fit(X_train,y_train)
# Out:
# KNeighborsRegressor()

# %%
predictions_knn = knn.predict(X_test)

# %%
mae_knn = metrics.mean_absolute_error(y_test,predictions_knn)
mse_knn = metrics.mean_squared_error(y_test,predictions_knn)
rmse_knn = np.sqrt(metrics.mean_squared_error(y_test,predictions_knn))
r2_knn = metrics.r2_score(y_test,predictions_knn)
mape_knn = metrics.mean_absolute_percentage_error(y_test,predictions_knn)

# %%
print('MAE :'," ", mae_knn)
print('MSE :'," ", mse_knn)
print('RMSE :'," ", rmse_knn) 
print('R2:'," ", r2_knn) 
print('MAPE:'," ", mape_knn)
# Out:
# MAE :   36684.202230483264
# MSE :   2374625505.234795
# RMSE :   48730.129337349346
# R2:   0.37895613935196526
# MAPE:   0.5634895083518132

# %%
knn = {
    'Metric': ['MAE', 'MSE', 'RMSE', 'R2', 'MAPE'],
    'Value': [mae_knn, mse_knn, rmse_knn, r2_knn, mape_knn]
}
knn_results = pd.DataFrame(knn)

# %%
knn_results
# Out:
#   Metric         Value
# 0    MAE  3.668420e+04
# 1    MSE  2.374626e+09
# 2   RMSE  4.873013e+04
# 3     R2  3.789561e-01
# 4   MAPE  5.634895e-01

# %% [markdown]
# - Catboost

# %%
cb = CatBoostRegressor()
cb.fit(X_train,y_train)
# Out:
# Learning rate set to 0.041401
# 0:	learn: 60782.5351641	total: 142ms	remaining: 2m 22s
# 1:	learn: 59961.7225093	total: 145ms	remaining: 1m 12s
# 2:	learn: 59137.2258702	total: 147ms	remaining: 48.8s
# 3:	learn: 58184.2561056	total: 149ms	remaining: 37.1s
# 4:	learn: 57252.6011930	total: 151ms	remaining: 30.1s
# 5:	learn: 56404.4411356	total: 153ms	remaining: 25.4s
# 6:	learn: 55806.6307505	total: 156ms	remaining: 22.2s
# 7:	learn: 55057.2573081	total: 158ms	remaining: 19.7s
# 8:	learn: 54453.2576845	total: 160ms	remaining: 17.6s
# 9:	learn: 53786.4454211	total: 162ms	remaining: 16.1s
# 10:	learn: 53318.8498568	total: 166ms	remaining: 14.9s
# 11:	learn: 52722.2341607	total: 169ms	remaining: 13.9s
# 12:	learn: 52232.0311593	total: 171ms	remaining: 13s
# 13:	learn: 51709.4211553	total: 174ms	remaining: 12.2s
# 14:	learn: 51190.7576943	total: 176ms	remaining: 11.6s
# 15:	learn: 50713.5779123	total: 179ms	remaining: 11s
# 16:	learn: 50292.6271704	total: 182ms	remaining: 10.5s
# ...

# %%
predictions_cb = cb.predict(X_test)

# %%
mae_cb = metrics.mean_absolute_error(y_test,predictions_cb)
mse_cb = metrics.mean_squared_error(y_test,predictions_cb)
rmse_cb = np.sqrt(metrics.mean_squared_error(y_test,predictions_cb))
r2_cb = metrics.r2_score(y_test,predictions_cb)
mape_cb = metrics.mean_absolute_percentage_error(y_test,predictions_cb)

# %%
print('MAE :'," ", mae_cb)
print('MSE :'," ", mse_cb)
print('RMSE :'," ", rmse_cb) 
print('R2:'," ", r2_cb) 
print('MAPE:'," ", mape_cb)
# Out:
# MAE :   32667.583786251467
# MSE :   1762409762.592649
# RMSE :   41981.06433372847
# R2:   0.5390709985252595
# MAPE:   0.42261770057777603

# %%
cb = {
    'Metric': ['MAE', 'MSE', 'RMSE', 'R2', 'MAPE'],
    'Value': [mae_cb, mse_cb, rmse_cb, r2_cb, mape_cb]
}
cb_results = pd.DataFrame(cb)

# %%
cb_results
# Out:
#   Metric         Value
# 0    MAE  3.266758e+04
# 1    MSE  1.762410e+09
# 2   RMSE  4.198106e+04
# 3     R2  5.390710e-01
# 4   MAPE  4.226177e-01

# %% [markdown]
# - Baggin Regressor

# %%
bg = BaggingRegressor()
bg.fit(X_train, y_train)
predictions_bg = bg.predict(X_test)

# %%
mae_bg = metrics.mean_absolute_error(y_test,predictions_bg)
mse_bg = metrics.mean_squared_error(y_test,predictions_bg)
rmse_bg = np.sqrt(metrics.mean_squared_error(y_test,predictions_bg))
r2_bg = metrics.r2_score(y_test,predictions_bg)
mape_bg = metrics.mean_absolute_percentage_error(y_test,predictions_bg)

# %%
print('MAE :'," ", mae_bg)
print('MSE :'," ", mse_bg)
print('RMSE :'," ", rmse_bg) 
print('R2:'," ", r2_bg) 
print('MAPE:'," ", mape_bg)
# Out:
# MAE :   37774.02936802973
# MSE :   2436863226.0894055
# RMSE :   49364.59486402583
# R2:   0.36267889717113555
# MAPE:   0.41017774779592636

# %%
bg = {
    'Metric': ['MAE', 'MSE', 'RMSE', 'R2', 'MAPE'],
    'Value': [mae_bg, mse_bg, rmse_bg, r2_bg, mape_bg]
}
bg_results = pd.DataFrame(bg)

# %%
bg_results
# Out:
#   Metric         Value
# 0    MAE  3.777403e+04
# 1    MSE  2.436863e+09
# 2   RMSE  4.936459e+04
# 3     R2  3.626789e-01
# 4   MAPE  4.101777e-01

# %% [markdown]
# - ADA Boost

# %%
ada = AdaBoostRegressor()
ada.fit(X_train, y_train)
predictions_ada = ada.predict(X_test)

# %%
mae_ada = metrics.mean_absolute_error(y_test, predictions_ada)
mse_ada = metrics.mean_squared_error(y_test, predictions_ada)
rmse_ada = np.sqrt(metrics.mean_squared_error(y_test, predictions_ada))
r2_ada = metrics.r2_score(y_test, predictions_ada)
mape_ada = metrics.mean_absolute_percentage_error(y_test, predictions_ada)

# %%
print('MAE :'," ", mae_ada)
print('MSE :'," ", mse_ada)
print('RMSE :'," ", rmse_ada) 
print('R2:'," ", r2_ada) 
print('MAPE:'," ", mape_ada)
# Out:
# MAE :   39263.58156089425
# MSE :   2363399888.9251204
# RMSE :   48614.81141509365
# R2:   0.38189201285106866
# MAPE:   0.5969587527954652

# %%
ada = {
    'Metric': ['MAE', 'MSE', 'RMSE', 'R2', 'MAPE'],
    'Value': [mae_ada, mse_ada, rmse_ada, r2_ada, mape_ada]
}
ada_results = pd.DataFrame(ada)

# %%
ada_results
# Out:
#   Metric         Value
# 0    MAE  3.926358e+04
# 1    MSE  2.363400e+09
# 2   RMSE  4.861481e+04
# 3     R2  3.818920e-01
# 4   MAPE  5.969588e-01

# %% [markdown]
# ### **Resumen resultados**

# %%
resumen = {
    'Model': ['Linear', 'Logistic', 'Lasso', 'Ridge', 'Random Forest', 'Decission Tree', 'Support Vector Machine', 'Gradient Boosting', 'KNN', 'CatBoost', 'Bagging', 'AdaBoost'],
    'R2': [r2_lr, r2_lg, r2_lasso, r2_ridge, r2_rf, r2_dt, r2_svm, r2_gbc, r2_knn, r2_cb, r2_bg, r2_ada],
    'MAE': [mae_lr, mae_lg, mae_lasso, mae_ridge, mae_rf, mae_dt, mae_svm, mae_gbc, mae_knn, mae_cb, mae_bg, mae_ada],
    'MAPE': [mape_lr, mape_lg, mape_lasso, mape_ridge, mape_rf, mape_dt, mape_svm, mape_gbc, mape_knn, mape_cb, mape_bg, mape_ada],
    'MSE': [mse_lr, mse_lg, mse_lasso, mse_ridge, mse_rf, mse_dt, mse_svm, mse_gbc, mse_knn, mse_cb, mse_bg, mse_ada],
    'RMSE': [rmse_lr, rmse_lg, rmse_lasso, rmse_ridge, rmse_rf, rmse_dt, rmse_svm, rmse_gbc, rmse_knn, rmse_cb, rmse_bg, rmse_ada]  
}
resumen = pd.DataFrame(resumen)

# %%
resumen
# Out:
#                      Model            R2           MAE          MAPE  \
# 0                   Linear -5.486155e+25  6.274625e+16  3.317434e+12
# 1                 Logistic  1.439233e-01  4.454218e+04  5.707760e-01
# 2                    Lasso  4.440522e-01  3.551398e+04  5.269198e-01
# 3                    Ridge  4.697290e-01  3.505925e+04  4.859185e-01
# 4            Random Forest  3.429679e-01  3.826463e+04  4.347033e-01
# 5           Decission Tree -2.861949e-02  4.810741e+04  4.469586e-01
# 6   Support Vector Machine -7.446232e-03  4.977776e+04  1.002912e+00
# 7        Gradient Boosting  5.251207e-01  3.330997e+04  4.158272e-01
# 8                      KNN  3.789561e-01  3.668420e+04  5.634895e-01
# 9                 CatBoost  5.390710e-01  3.266758e+04  4.226177e-01
# 10                 Bagging  3.626789e-01  3.777403e+04  4.101777e-01
# 11                AdaBoost  3.818920e-01  3.926358e+04  5.969588e-01
#
#              MSE          RMSE
# 0   2.097688e+35  4.580053e+17
# ...

# %% [markdown]
# **GRIDSEARCH**

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import GradientBoostingRegressor
from catboost import CatBoostRegressor
from sklearn.linear_model import Lasso
from sklearn.linear_model import Ridge

models = {

    'Catboost': (CatBoostRegressor(), {'learning_rate': [0.1, 0.01],'depth': [4, 6, 8],'l2_leaf_reg': [1, 3, 5],'iterations': [100, 200]})
}

for model_name, (model, param_grid) in models.items():
    print(f"Grid Search para el modelo {model_name}:")
    grid_search = GridSearchCV(model, param_grid, cv=5, scoring='r2')
    grid_search.fit(X_train, y_train)
    best_params = grid_search.best_params_
    best_score = grid_search.best_score_
    print(f"Mejores parámetros: {best_params}")
    print(f"Puntuación cruzada (cross-validation) del mejor modelo: {best_score}\n")
# Out:
# Grid Search para el modelo Catboost:
# 0:	learn: 59664.0431058	total: 1.72ms	remaining: 170ms
# 1:	learn: 57600.7499881	total: 3.36ms	remaining: 165ms
# 2:	learn: 55949.9618359	total: 4.93ms	remaining: 160ms
# 3:	learn: 54416.9733415	total: 7.11ms	remaining: 171ms
# 4:	learn: 53359.4366196	total: 10.4ms	remaining: 198ms
# 5:	learn: 52325.2415201	total: 14.8ms	remaining: 233ms
# 6:	learn: 51454.4121443	total: 16.8ms	remaining: 223ms
# 7:	learn: 50822.5842829	total: 18.4ms	remaining: 212ms
# 8:	learn: 50042.7472949	total: 21.2ms	remaining: 214ms
# 9:	learn: 49449.0951512	total: 23.6ms	remaining: 212ms
# 10:	learn: 48895.2690607	total: 25.7ms	remaining: 208ms
# 11:	learn: 48138.3614711	total: 28.3ms	remaining: 208ms
# 12:	learn: 47625.5238439	total: 30.7ms	remaining: 206ms
# 13:	learn: 47250.4291958	total: 34.4ms	remaining: 211ms
# 14:	learn: 46957.0104503	total: 41.9ms	remaining: 237ms
# 15:	learn: 46749.3998587	total: 43.6ms	remaining: 229ms
# ...

# %% [markdown]
# - Catboost

# %%
cb2 = CatBoostRegressor(depth=8, iterations = 100, l2_leaf_reg= 5, learning_rate = 0.1)
cb2.fit(X_train,y_train)
predictions_cb2 = cb2.predict(X_test)

mae_cb2 = metrics.mean_absolute_error(y_test,predictions_cb2)
mse_cb2 = metrics.mean_squared_error(y_test,predictions_cb2)
rmse_cb2 = np.sqrt(metrics.mean_squared_error(y_test,predictions_cb2))
r2_cb2 = metrics.r2_score(y_test,predictions_cb2)
mape_cb2 = metrics.mean_absolute_percentage_error(y_test,predictions_cb2)
# Out:
# 0:	learn: 59733.7193667	total: 8.81ms	remaining: 873ms
# 1:	learn: 58015.1052483	total: 14.7ms	remaining: 722ms
# 2:	learn: 56363.7854463	total: 34.8ms	remaining: 1.13s
# 3:	learn: 54680.9913150	total: 42.6ms	remaining: 1.02s
# 4:	learn: 53307.4957767	total: 54.5ms	remaining: 1.03s
# 5:	learn: 51978.6974684	total: 63.7ms	remaining: 998ms
# 6:	learn: 50995.7262572	total: 73.9ms	remaining: 982ms
# 7:	learn: 50260.0922232	total: 76.1ms	remaining: 875ms
# 8:	learn: 49502.8288841	total: 84.5ms	remaining: 855ms
# 9:	learn: 48627.4940202	total: 90.3ms	remaining: 812ms
# 10:	learn: 47956.1752442	total: 99.4ms	remaining: 804ms
# 11:	learn: 47482.2665395	total: 130ms	remaining: 950ms
# 12:	learn: 46903.8149146	total: 137ms	remaining: 920ms
# 13:	learn: 46471.7122723	total: 141ms	remaining: 869ms
# 14:	learn: 46180.4441313	total: 149ms	remaining: 845ms
# 15:	learn: 45825.3202748	total: 153ms	remaining: 803ms
# 16:	learn: 45487.4719160	total: 163ms	remaining: 797ms
# ...

# %%
print('MAE :'," ", mae_cb2)
print('MSE :'," ", mse_cb2)
print('RMSE :'," ", rmse_cb2) 
print('R2:'," ", r2_cb2) 
print('MAPE:'," ", mape_cb2)
# Out:
# MAE :   33801.57056797382
# MSE :   1847353113.683249
# RMSE :   42980.84589306321
# R2:   0.5168554758748904
# MAPE:   0.4718192157062722

# %% [markdown]
# **Comparación resultados**

# %%
comparación_salarios = pd.DataFrame({'Salarios': y_test, 'Predicción salarios': predictions_cb, 'Error': y_test - predictions_cb})

# %%
comparación_salarios['Error'] = comparación_salarios['Error'].abs()

# %%
menor_error = comparación_salarios.sort_values(by='Error', ascending=True)

# %%
menor_error.head(10)
# Out:
#       Salarios  Predicción salarios        Error
# 538     192000        191702.207230   297.792770
# 744      78000         77592.538057   407.461943
# 767     130000        129479.294242   520.705758
# 196     115934        115180.014277   753.985723
# 598     115934        116762.514585   828.514585
# 1289    103691        104653.736046   962.736046
# 493      54094         55267.167508  1173.167508
# 175      83500         84677.948493  1177.948493
# 247     239000        240312.821424  1312.821424
# 163     145000        146481.429370  1481.429370

# %% [markdown]
# Los 10 salarios con menor predicción de error, se sitúan entre los $54.094 y los $239.000.

# %%
mayor_error = comparación_salarios.sort_values(by='Error', ascending=False)

# %%
mayor_error.head(10)
# Out:
#      Salarios  Predicción salarios          Error
# 693    315000        163617.715444  151382.284556
# 297    290000        160866.234879  129133.765121
# 221    276000        154640.852865  121359.147135
# 350     63000        171561.303303  108561.303303
# 447    250000        145906.575388  104093.424612
# 894    250000        147936.359812  102063.640188
# 898    250000        147936.359812  102063.640188
# 23     110500        204702.838957   94202.838957
# 433     75000        167256.048030   92256.048030
# 765     38000        129479.294242   91479.294242

# %% [markdown]
# Los 10 salarios con mayor predicción de error se sitúan entre los $38.000 y los $315.300.
